# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('loan_data_2007_2014.csv')
# Out:
# C:\Users\Anticus\AppData\Local\Temp\ipykernel_9632\1926087617.py:1: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('loan_data_2007_2014.csv')

# %%
default_loans = ['Charged Off', 'Default', 'Does not meet the credit policy. Status:Charged Off', 'Late (31-120 days)']

data['good_bad'] = np.where(data['loan_status'].isin(default_loans), 0, 1)

# %%
inputs_train, input_test, targets_train, targets_test = train_test_split(data.drop('good_bad', axis=1),
                                                                          data['good_bad'],
                                                                          train_size = 0.25,
                                                                          random_state = 102)

# %%
data_acutal = pd.concat([inputs_train, targets_train], axis=1)

# %%
data_acutal.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       5000         5000           5000.0   36 months
# 1 NaN        NaN      10000        10000          10000.0   60 months
# 2 NaN        NaN      11000        11000          11000.0   36 months
# 3 NaN        NaN      24250        24250          24250.0   60 months
# 4 NaN        NaN      35000        35000          35000.0   36 months
#
#    int_rate  installment grade sub_grade  ... hardship_last_payment_amount  \
# 0     10.41       162.31     B        B3  ...                          NaN
# 1     10.42       214.55     B        B3  ...                          NaN
# 2     11.14       360.86     B        B2  ...                          NaN
# 3     13.18       554.00     C        C3  ...                          NaN
# 4     10.07      1130.51     B        B2  ...                          NaN
#
#   disbursement_method debt_settlement_flag  debt_settlement_flag_date  \
# ...

# %%
data_acutal.reset_index(inplace=True, drop=True)

# %%
data_acutal.to_csv('new_data.csv')
